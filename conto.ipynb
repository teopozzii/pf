# %% [markdown]
# # Personal finance
# This notebook aims at analyzing features of personal expenditure, especially
# - gross amounts per spending category
# - relative shares of each spending category
# - spending sustainability in light of income and other inflow sources

# %%
import openpyxl
import pandas as pd

# %%
# Read excel file and select relevant columns
estratto = pd.read_excel('conti_consolidati.xlsx',sheet_name='FULL', usecols=list(range(18)))
estratto['USCITE'].fillna(0)

estratto.drop(
    labels=['DATA OPERAZIONE', 'DATA VALUTA', 'GIORNO','MESE','ANNO'], 
    axis=1, inplace=True)

estratto.sort_values(by='DATA FORMATTATA')
estratto.head()
